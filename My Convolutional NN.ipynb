# %%
'''
A Convolutional Network implementation example using TensorFlow library.
This example is using the MNIST database of handwritten digits
(http://yann.lecun.com/exdb/mnist/)
Author: Aymeric Damien
Project: https://github.com/aymericdamien/TensorFlow-Examples/
'''

from __future__ import print_function

import tensorflow as tf

# %%
# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)

# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)


# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# %%
# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")

    # Calculate accuracy for 256 mnist test images
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.}))
# Out:
# Iter 1280, Minibatch Loss= 22643.890625, Training Accuracy= 0.30469
# Iter 2560, Minibatch Loss= 9424.340820, Training Accuracy= 0.59375
# Iter 3840, Minibatch Loss= 4599.752441, Training Accuracy= 0.75781
# Iter 5120, Minibatch Loss= 3750.604004, Training Accuracy= 0.78906
# Iter 6400, Minibatch Loss= 4827.330566, Training Accuracy= 0.73438
# Iter 7680, Minibatch Loss= 2755.130615, Training Accuracy= 0.82812
# Iter 8960, Minibatch Loss= 3975.289795, Training Accuracy= 0.78906
# Iter 10240, Minibatch Loss= 2522.802979, Training Accuracy= 0.82812
# Iter 11520, Minibatch Loss= 1070.782715, Training Accuracy= 0.89062
# Iter 12800, Minibatch Loss= 1658.659424, Training Accuracy= 0.91406
# Iter 14080, Minibatch Loss= 1904.819336, Training Accuracy= 0.87500
# Iter 15360, Minibatch Loss= 1069.649658, Training Accuracy= 0.92969
# Iter 16640, Minibatch Loss= 2566.541504, Training Accuracy= 0.86719
# Iter 17920, Minibatch Loss= 1854.991943, Training Accuracy= 0.91406
# Iter 19200, Minibatch Loss= 1265.042480, Training Accuracy= 0.91406
# Iter 20480, Minibatch Loss= 1674.761719, Training Accuracy= 0.90625
# Iter 21760, Minibatch Loss= 1936.108643, Training Accuracy= 0.89062
# Iter 23040, Minibatch Loss= 1741.803467, Training Accuracy= 0.93750
# Iter 24320, Minibatch Loss= 1450.253540, Training Accuracy= 0.91406
# Iter 25600, Minibatch Loss= 544.423279, Training Accuracy= 0.92969
# Iter 26880, Minibatch Loss= 879.989868, Training Accuracy= 0.94531
# Iter 28160, Minibatch Loss= 894.463623, Training Accuracy= 0.92188
# Iter 29440, Minibatch Loss= 547.874756, Training Accuracy= 0.93750
# Iter 30720, Minibatch Loss= 1068.648438, Training Accuracy= 0.94531
# Iter 32000, Minibatch Loss= 935.130127, Training Accuracy= 0.89844
# Iter 33280, Minibatch Loss= 395.981293, Training Accuracy= 0.93750
# Iter 34560, Minibatch Loss= 867.065796, Training Accuracy= 0.94531
# Iter 35840, Minibatch Loss= 1141.688965, Training Accuracy= 0.92188
# Iter 37120, Minibatch Loss= 939.691772, Training Accuracy= 0.92969
# Iter 38400, Minibatch Loss= 830.757629, Training Accuracy= 0.92969
# Iter 39680, Minibatch Loss= 1075.588379, Training Accuracy= 0.92969
# Iter 40960, Minibatch Loss= 496.034088, Training Accuracy= 0.94531
# Iter 42240, Minibatch Loss= 1316.615967, Training Accuracy= 0.92188
# Iter 43520, Minibatch Loss= 907.298889, Training Accuracy= 0.90625
# Iter 44800, Minibatch Loss= 373.746704, Training Accuracy= 0.96094
# Iter 46080, Minibatch Loss= 592.373413, Training Accuracy= 0.95312
# Iter 47360, Minibatch Loss= 659.632507, Training Accuracy= 0.92969
# Iter 48640, Minibatch Loss= 1530.861816, Training Accuracy= 0.89062
# Iter 49920, Minibatch Loss= 378.947327, Training Accuracy= 0.95312
# Iter 51200, Minibatch Loss= 1052.873047, Training Accuracy= 0.92969
# Iter 52480, Minibatch Loss= 801.929688, Training Accuracy= 0.93750
# Iter 53760, Minibatch Loss= 536.622803, Training Accuracy= 0.92188
# Iter 55040, Minibatch Loss= 332.705505, Training Accuracy= 0.97656
# Iter 56320, Minibatch Loss= 894.344482, Training Accuracy= 0.95312
# Iter 57600, Minibatch Loss= 187.198563, Training Accuracy= 0.96094
# Iter 58880, Minibatch Loss= 489.657410, Training Accuracy= 0.95312
# Iter 60160, Minibatch Loss= 183.202118, Training Accuracy= 0.96875
# Iter 61440, Minibatch Loss= 461.627136, Training Accuracy= 0.96875
# Iter 62720, Minibatch Loss= 741.759888, Training Accuracy= 0.93750
# Iter 64000, Minibatch Loss= 503.419434, Training Accuracy= 0.94531
# Iter 65280, Minibatch Loss= 302.378387, Training Accuracy= 0.96875
# Iter 66560, Minibatch Loss= 528.379517, Training Accuracy= 0.93750
# Iter 67840, Minibatch Loss= 222.246246, Training Accuracy= 0.95312
# Iter 69120, Minibatch Loss= 399.191101, Training Accuracy= 0.96094
# Iter 70400, Minibatch Loss= 410.944458, Training Accuracy= 0.96094
# Iter 71680, Minibatch Loss= 77.051147, Training Accuracy= 0.98438
# Iter 72960, Minibatch Loss= 433.858063, Training Accuracy= 0.96094
# Iter 74240, Minibatch Loss= 535.758911, Training Accuracy= 0.96094
# Iter 75520, Minibatch Loss= 295.143799, Training Accuracy= 0.94531
# Iter 76800, Minibatch Loss= 283.282959, Training Accuracy= 0.96875
# Iter 78080, Minibatch Loss= 390.814636, Training Accuracy= 0.96094
# Iter 79360, Minibatch Loss= 633.020386, Training Accuracy= 0.94531
# Iter 80640, Minibatch Loss= 658.155457, Training Accuracy= 0.96094
# Iter 81920, Minibatch Loss= 590.263367, Training Accuracy= 0.91406
# Iter 83200, Minibatch Loss= 290.994873, Training Accuracy= 0.95312
# Iter 84480, Minibatch Loss= 983.639648, Training Accuracy= 0.94531
# Iter 85760, Minibatch Loss= 444.108582, Training Accuracy= 0.96094
# Iter 87040, Minibatch Loss= 458.637756, Training Accuracy= 0.96094
# Iter 88320, Minibatch Loss= 170.344025, Training Accuracy= 0.97656
# Iter 89600, Minibatch Loss= 675.809448, Training Accuracy= 0.95312
# Iter 90880, Minibatch Loss= 689.490845, Training Accuracy= 0.95312
# Iter 92160, Minibatch Loss= 303.173553, Training Accuracy= 0.96875
# Iter 93440, Minibatch Loss= 305.249390, Training Accuracy= 0.96875
# Iter 94720, Minibatch Loss= 271.024078, Training Accuracy= 0.96875
# Iter 96000, Minibatch Loss= 359.924774, Training Accuracy= 0.96094
# Iter 97280, Minibatch Loss= 110.515396, Training Accuracy= 0.97656
# Iter 98560, Minibatch Loss= 108.400757, Training Accuracy= 0.97656
# Iter 99840, Minibatch Loss= 116.826462, Training Accuracy= 0.99219
# Iter 101120, Minibatch Loss= 100.048813, Training Accuracy= 0.96875
# Iter 102400, Minibatch Loss= 386.605194, Training Accuracy= 0.97656
# Iter 103680, Minibatch Loss= 527.261230, Training Accuracy= 0.94531
# Iter 104960, Minibatch Loss= 168.480530, Training Accuracy= 0.96875
# Iter 106240, Minibatch Loss= 307.550293, Training Accuracy= 0.94531
# Iter 107520, Minibatch Loss= 271.705780, Training Accuracy= 0.95312
# Iter 108800, Minibatch Loss= 406.514587, Training Accuracy= 0.92188
# Iter 110080, Minibatch Loss= 264.235840, Training Accuracy= 0.97656
# Iter 111360, Minibatch Loss= 164.570404, Training Accuracy= 0.97656
# Iter 112640, Minibatch Loss= 215.877197, Training Accuracy= 0.97656
# Iter 113920, Minibatch Loss= 202.000763, Training Accuracy= 0.97656
# Iter 115200, Minibatch Loss= 383.976715, Training Accuracy= 0.96875
# Iter 116480, Minibatch Loss= 290.356232, Training Accuracy= 0.96875
# Iter 117760, Minibatch Loss= 350.304993, Training Accuracy= 0.94531
# Iter 119040, Minibatch Loss= 432.042633, Training Accuracy= 0.93750
# Iter 120320, Minibatch Loss= 21.298637, Training Accuracy= 0.98438
# Iter 121600, Minibatch Loss= 347.333893, Training Accuracy= 0.97656
# Iter 122880, Minibatch Loss= 46.537251, Training Accuracy= 0.98438
# Iter 124160, Minibatch Loss= 44.289581, Training Accuracy= 0.97656
# Iter 125440, Minibatch Loss= 187.026154, Training Accuracy= 0.96875
# Iter 126720, Minibatch Loss= 312.943634, Training Accuracy= 0.95312
# Iter 128000, Minibatch Loss= 254.781738, Training Accuracy= 0.94531
# Iter 129280, Minibatch Loss= 325.318848, Training Accuracy= 0.97656
# Iter 130560, Minibatch Loss= 110.022476, Training Accuracy= 0.96094
# Iter 131840, Minibatch Loss= 156.786514, Training Accuracy= 0.97656
# Iter 133120, Minibatch Loss= 0.482773, Training Accuracy= 0.99219
# Iter 134400, Minibatch Loss= 277.598450, Training Accuracy= 0.95312
# Iter 135680, Minibatch Loss= 116.620422, Training Accuracy= 0.98438
# Iter 136960, Minibatch Loss= 468.973450, Training Accuracy= 0.92188
# Iter 138240, Minibatch Loss= 228.016922, Training Accuracy= 0.96094
# Iter 139520, Minibatch Loss= 307.805603, Training Accuracy= 0.95312
# Iter 140800, Minibatch Loss= 190.017700, Training Accuracy= 0.94531
# Iter 142080, Minibatch Loss= 261.583435, Training Accuracy= 0.96094
# Iter 143360, Minibatch Loss= 3.851532, Training Accuracy= 0.99219
# Iter 144640, Minibatch Loss= 144.182175, Training Accuracy= 0.97656
# Iter 145920, Minibatch Loss= 319.280853, Training Accuracy= 0.93750
# Iter 147200, Minibatch Loss= 68.119720, Training Accuracy= 0.96875
# Iter 148480, Minibatch Loss= 94.833679, Training Accuracy= 0.97656
# Iter 149760, Minibatch Loss= 1.619034, Training Accuracy= 0.99219
# Iter 151040, Minibatch Loss= 166.534302, Training Accuracy= 0.96875
# Iter 152320, Minibatch Loss= 29.188156, Training Accuracy= 0.98438
# Iter 153600, Minibatch Loss= 91.667496, Training Accuracy= 0.98438
# Iter 154880, Minibatch Loss= 234.321854, Training Accuracy= 0.97656
# Iter 156160, Minibatch Loss= 117.092102, Training Accuracy= 0.96875
# Iter 157440, Minibatch Loss= 107.298882, Training Accuracy= 0.97656
# Iter 158720, Minibatch Loss= 94.061844, Training Accuracy= 0.96875
# Iter 160000, Minibatch Loss= 275.629425, Training Accuracy= 0.96875
# Iter 161280, Minibatch Loss= 177.570221, Training Accuracy= 0.96875
# Iter 162560, Minibatch Loss= 130.946106, Training Accuracy= 0.97656
# Iter 163840, Minibatch Loss= 97.821228, Training Accuracy= 0.98438
# Iter 165120, Minibatch Loss= 96.250168, Training Accuracy= 0.96875
# Iter 166400, Minibatch Loss= 38.271454, Training Accuracy= 0.98438
# Iter 167680, Minibatch Loss= 33.972046, Training Accuracy= 0.97656
# Iter 168960, Minibatch Loss= 499.511383, Training Accuracy= 0.96094
# Iter 170240, Minibatch Loss= 472.988159, Training Accuracy= 0.95312
# Iter 171520, Minibatch Loss= 64.035767, Training Accuracy= 0.98438
# Iter 172800, Minibatch Loss= 359.595551, Training Accuracy= 0.95312
# Iter 174080, Minibatch Loss= 32.783188, Training Accuracy= 0.98438
# Iter 175360, Minibatch Loss= 70.885612, Training Accuracy= 0.97656
# Iter 176640, Minibatch Loss= 55.864822, Training Accuracy= 0.99219
# Iter 177920, Minibatch Loss= 143.892441, Training Accuracy= 0.98438
# Iter 179200, Minibatch Loss= 94.940842, Training Accuracy= 0.97656
# Iter 180480, Minibatch Loss= 135.524597, Training Accuracy= 0.97656
# Iter 181760, Minibatch Loss= 221.042267, Training Accuracy= 0.96094
# Iter 183040, Minibatch Loss= 113.987007, Training Accuracy= 0.97656
# Iter 184320, Minibatch Loss= 85.278946, Training Accuracy= 0.97656
# Iter 185600, Minibatch Loss= 211.286743, Training Accuracy= 0.96094
# Iter 186880, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 188160, Minibatch Loss= 226.735413, Training Accuracy= 0.96875
# Iter 189440, Minibatch Loss= 106.106567, Training Accuracy= 0.98438
# Iter 190720, Minibatch Loss= 79.808395, Training Accuracy= 0.97656
# Iter 192000, Minibatch Loss= 125.023895, Training Accuracy= 0.98438
# Iter 193280, Minibatch Loss= 131.446274, Training Accuracy= 0.98438
# Iter 194560, Minibatch Loss= 123.262283, Training Accuracy= 0.98438
# Iter 195840, Minibatch Loss= 71.772453, Training Accuracy= 0.97656
# Iter 197120, Minibatch Loss= 77.712036, Training Accuracy= 0.97656
# Iter 198400, Minibatch Loss= 134.698196, Training Accuracy= 0.97656
# Iter 199680, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Optimization Finished!
# Testing Accuracy: 0.988281

# %%
import os
cwd = os.getcwd()

# %%
cwd
# Out:
# '/home/ubuntu/pynb/udacity'
